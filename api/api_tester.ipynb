# %%
import pandas as pd
import random
import pickle
import json
import requests
from rossmann.Rossmann import Rossmann

# %%
# load production data
df_stores_raw = pd.read_csv('C:/Users/andre/repos/ds-em-producao/data/store.csv', low_memory=False)
df12 = pd.read_csv('C:/Users/andre/repos/ds-em-producao/data/test.csv')
df12 = pd.merge(df12, df_stores_raw, how='left', on='Store')
#df12 = df12.loc[df12['Store'].isin(stores), :].reset_index(drop=True)
df12 = df12[df12['Store'] <= 500].reset_index(drop=True)

# %%
# Teste Class
pipeline = Rossmann()

# %%
# data_cleaning
df1 = pipeline.data_cleaning(df12)
df1.head()
# Out:
#    id  store  day_of_week       date  open  promo state_holiday  \
# 0   1      1            4 2015-09-17   1.0      1             0
# 1   2      3            4 2015-09-17   1.0      1             0
# 2   3      7            4 2015-09-17   1.0      1             0
# 3   4      8            4 2015-09-17   1.0      1             0
# 4   5      9            4 2015-09-17   1.0      1             0
#
#    school_holiday store_type assortment  competition_distance  \
# 0               0          c          a                1270.0
# 1               0          a          a               14130.0
# 2               0          a          c               24000.0
# 3               0          a          a                7520.0
# 4               0          a          c                2030.0
#
#    competition_open_since_month  competition_open_since_year  promo2  \
# 0                             9                         2008       0
# ...

# %%
df2 = pipeline.feature_engineering(df1)
df2.head()
# Out:
#    id  store  day_of_week       date  promo state_holiday  school_holiday  \
# 0   1      1            4 2015-09-17      1    no_holiday               0
# 1   2      3            4 2015-09-17      1    no_holiday               0
# 2   3      7            4 2015-09-17      1    no_holiday               0
# 3   4      8            4 2015-09-17      1    no_holiday               0
# 4   5      9            4 2015-09-17      1    no_holiday               0
#
#   store_type assortment  competition_distance  ...  is_promo  year  month  \
# 0          c      basic                1270.0  ...         0  2015      9
# 1          a      basic               14130.0  ...         0  2015      9
# 2          a   extended               24000.0  ...         0  2015      9
# 3          a      basic                7520.0  ...         0  2015      9
# 4          a   extended                2030.0  ...         0  2015      9
#
# ...

# %%
df3 = pipeline.data_preparation(df2)
df3.head()
# Out:
#    store  promo  store_type  assortment  competition_distance  \
# 0      1      1           2           1             -0.252951
# 1      3      1           0           1              1.915683
# 2      7      1           0           3              3.580101
# 3      8      1           0           1              0.801012
# 4      9      1           0           3             -0.124789
#
#    competition_open_since_year  promo2  promo2_since_year  \
# 0                         2008       0               2015
# 1                         2006       1               2011
# 2                         2013       0               2015
# 3                         2014       0               2015
# 4                         2000       0               2015
#
#    competition_number_months  promo_number_weeks   day_sin   day_cos  \
# 0                   0.726190            0.000000 -0.406737 -0.913545
# 1                   0.988095            0.728125 -0.406737 -0.913545
# ...

# %%
model = pickle.load(open('C:/Users/andre/repos/ds-em-producao/models/rossman_model_v1.pkl', 'rb'))

pred = model.predict(df3)

# %%
pred
# Out:
# array([8.33147741, 8.87002642, 9.06341213, ..., 8.87292885, 8.44148791,
#        8.60870664])

# %%
# load production data
df_stores_raw = pd.read_csv('C:/Users/andre/repos/ds-em-producao/data/store.csv', low_memory=False)
df12 = pd.read_csv('C:/Users/andre/repos/ds-em-producao/data/test.csv')
df12 = pd.merge(df12, df_stores_raw, how='left', on='Store')
#df12 = df12.loc[df12['Store'].isin(stores), :].reset_index(drop=True)
df12 = df12[df12['Store'] <= 500].reset_index(drop=True)

df_test = df12[df12['Store'] == 12].reset_index(drop=True)

# convert df to json
data = json.dumps(df_test.to_dict(orient='records'))

# %%
#api call
url = 'http://0.0.0.0:5000/rossmann/predict'
header = {'Content-type': 'application/json'}
data = data

r = requests.post(url, data=data, headers=header)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\.conda\envs\ds_em_producao\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\.conda\envs\ds_em_producao\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\.conda\envs\ds_em_producao\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...
